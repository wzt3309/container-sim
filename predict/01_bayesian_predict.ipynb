# %% [markdown]
# # 贝叶斯回归

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from sklearn.linear_model import BayesianRidge
from sklearn.model_selection import TimeSeriesSplit

import read_data as rd
from metrics import cwcf, picpf, pinewf

# %%
ts_sm, ts_tr, ts_pe = rd.load_sp()

# %%
ts = ts_sm

# %%
ts_u_train, ts_u_test, ts_l_train, ts_l_test, ts_train, ts_test = rd.split_train_test(ts)

# %%
bay_u, bay_l = BayesianRidge(), BayesianRidge()

# %%
from predict_fx import xxx_cross_validation, xxx_test_validation, predict_diff, predict_sp_diff

# %%
xxx_cross_validation(ts_train, ts_u_train, ts_l_train, bay_u, bay_l, is_plot=True, plt_no=311)
# Out:
# (1.7877815557169274, 0.5972222222222222, 0.906702563235242)

# %%
xxx_test_validation(ts_test, ts_u_train, ts_u_test, ts_l_train, ts_l_test, bay_u, bay_l, is_plot=True)
# Out:
# (0.9242155592865575, 0.6588235294117647, 0.9242155592865575)

# %% [markdown]
# # 检验

# %% [markdown]
# ## 检验smooth

# %%
predict_diff(ts_sm, model='bayesian', is_plt=True)
# Out:
# bayesian
# Result of Cross validation:
# cwc 1.595751, picp 0.583333, pinew 0.819826
# Result of Test validation:
# cwc 0.924216, picp 0.658824, pinew 0.924216
# (0.9242155592865575, 0.6588235294117647, 0.9242155592865575)

# %% [markdown]
# ## 检验trend

# %%
predict_diff(ts_tr, model='bayesian', is_plt=True)
# Out:
# bayesian
# Result of Cross validation:
# cwc 1.440498, picp 0.701389, pinew 0.580754
# Result of Test validation:
# cwc 0.415382, picp 0.670588, pinew 0.415382
# (0.41538188061251663, 0.6705882352941176, 0.41538188061251663)

# %% [markdown]
# ## 检验period

# %%
predict_diff(ts_pe, model='bayesian', is_plt=True)
# Out:
# bayesian
# Result of Cross validation:
# cwc 1.364434, picp 0.625000, pinew 0.606406
# Result of Test validation:
# cwc 0.300186, picp 0.623529, pinew 0.300186
# (0.3001860425768476, 0.6235294117647059, 0.3001860425768476)

# %%
predict_sp_diff('bayesian')
# Out:
# bayesian
# bayesian
# Result of Cross validation:
# cwc 1.595751, picp 0.583333, pinew 0.819826
# Result of Test validation:
# cwc 0.924216, picp 0.658824, pinew 0.924216
# bayesian
# Result of Cross validation:
# cwc 1.440498, picp 0.701389, pinew 0.580754
# Result of Test validation:
# cwc 0.415382, picp 0.670588, pinew 0.415382
# bayesian
# Result of Cross validation:
# cwc 1.364434, picp 0.625000, pinew 0.606406
# Result of Test validation:
# cwc 0.300186, picp 0.623529, pinew 0.300186
#
# Final Result:
# cwc 0.546594, picp 0.650980, pinew 0.546594
