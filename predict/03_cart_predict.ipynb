# %% [markdown]
# # 分类回归树（决策树回归）

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import TimeSeriesSplit

import read_data as rd
from metrics import cwcf, picpf, pinewf

# %%
ts_sm, ts_tr, ts_pe = rd.load_sp()

# %%
ts = ts_sm

# %%
ts_u_train, ts_u_test, ts_l_train, ts_l_test, ts_train, ts_test = rd.split_train_test(ts)

# %%
tree_cv_u = DecisionTreeRegressor()
tree_cv_l = DecisionTreeRegressor()

tree_u = DecisionTreeRegressor()
tree_l = DecisionTreeRegressor()

# %%
from predict_fx import xxx_cross_validation, xxx_test_validation, predict_diff, predict_sp_diff

# %%
xxx_cross_validation(ts_train, ts_u_train, ts_l_train, tree_cv_u, tree_cv_l, is_plot=True, plt_no=311)
# Out:
# (1.2910876420081585, 0.5486111111111112, 0.5359824231942988)

# %%
xxx_test_validation(ts_test, ts_u_train, ts_u_test, ts_l_train, ts_l_test, tree_u, tree_l, is_plot=True)
# Out:
# (1.2567876405200338, 0.5647058823529412, 0.5186377708978333)

# %% [markdown]
# # 检验

# %% [markdown]
# ## 检验smooth

# %%
predict_diff(ts_sm, model='cart', is_plt=True)
# Out:
# cart
# Result of Cross validation:
# cwc 1.363577, picp 0.548611, pinew 0.528685
# Result of Test validation:
# cwc 1.270925, picp 0.564706, pinew 0.524472
# (1.2709251502303793, 0.5647058823529412, 0.5244718882027951)

# %% [markdown]
# ## 检验trend

# %%
predict_diff(ts_tr, model='cart', is_plt=True)
# Out:
# cart
# Result of Cross validation:
# cwc 1.559324, picp 0.513889, pinew 0.357812
# Result of Test validation:
# cwc 0.275353, picp 0.600000, pinew 0.275353
# (0.2753531095696195, 0.6, 0.2753531095696195)

# %% [markdown]
# ## 检验period

# %%
predict_diff(ts_pe, model='cart', is_plt=True)
# Out:
# cart
# Result of Cross validation:
# cwc 1.077863, picp 0.458333, pinew 0.373057
# Result of Test validation:
# cwc 0.751853, picp 0.458824, pinew 0.147330
# (0.7518527633708111, 0.4588235294117647, 0.14732995868970747)

# %%
predict_sp_diff('cart')
# Out:
# cart
# cart
# Result of Cross validation:
# cwc 1.307517, picp 0.548611, pinew 0.523472
# Result of Test validation:
# cwc 1.293805, picp 0.564706, pinew 0.533914
# cart
# Result of Cross validation:
# cwc 1.238234, picp 0.534722, pinew 0.360705
# Result of Test validation:
# cwc 0.683257, picp 0.552941, pinew 0.262697
# cart
# Result of Cross validation:
# cwc 1.076482, picp 0.465278, pinew 0.370673
# Result of Test validation:
# cwc 0.836160, picp 0.447059, pinew 0.148903
#
# Final Result:
# cwc 0.937741, picp 0.521569, pinew 0.315171
