# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from sklearn.svm import SVR
from sklearn.model_selection import TimeSeriesSplit

import read_data as rd
from metrics import cwcf, picpf, pinewf

# %%
ts_sm, ts_tr, ts_pe = rd.load_sp()

# %%
ts = ts_sm

# %%
ts_u_train, ts_u_test, ts_l_train, ts_l_test, ts_train, ts_test = rd.split_train_test(ts)

# %%
svr_cv_u = SVR(gamma=0.04395667, C=25)
svr_cv_l = SVR(gamma=0.22022829, C=20.8)
svr_u = SVR(gamma=0.04395667, C=25)
svr_l = SVR(gamma=0.22022829, C=20.8)

# %%
from predict_fx import xxx_cross_validation, xxx_test_validation, predict_diff, predict_sp_diff

# %%
xxx_cross_validation(ts_train, ts_u_train, ts_l_train, svr_cv_u, svr_cv_l, is_plot=True, plt_no=311)
# Out:
# (14.867279773751735, 0.611111111111111, 0.7024364540684105)

# %%
xxx_test_validation(ts_test, ts_u_train, ts_u_test, ts_l_train, ts_l_test, svr_u, svr_l, is_plot=True)
# Out:
# (8.659713908227014, 0.6470588235294118, 0.6392761484234394)

# %% [markdown]
# # 检验

# %% [markdown]
# ## 检验smooth

# %%
predict_diff(ts_sm, model='svm', is_plt=True)
# Out:
# svm
# Result of Cross validation:
# cwc 3.000581, picp 0.770833, pinew 0.604896
# Result of Test validation:
# cwc 1.317648, picp 0.894118, pinew 0.639453
# (1.31764829018348, 0.8941176470588236, 0.6394525498434185)

# %% [markdown]
# ## 检验trend

# %%
predict_diff(ts_tr, model='svm', is_plt=True)
# Out:
# svm
# Result of Cross validation:
# cwc 11.282261, picp 0.673611, pinew 0.403557
# Result of Test validation:
# cwc 0.923000, picp 0.847059, pinew 0.342114
# (0.9230000725174263, 0.8470588235294118, 0.34211375658473325)

# %% [markdown]
# ## 检验period

# %%
predict_diff(ts_pe, model='svm', is_plt=True)
# Out:
# svm
# Result of Cross validation:
# cwc 2.119213, picp 0.548611, pinew 0.265893
# Result of Test validation:
# cwc 1.192491, picp 0.764706, pinew 0.244926
# (1.1924909131478238, 0.7647058823529411, 0.24492563877522872)

# %%
predict_sp_diff('svm')
# Out:
# Using svm 'model' to predict
# svm
# Result of Cross validation:
# cwc 3.000581, picp 0.770833, pinew 0.604896
# Result of Test validation:
# cwc 1.317648, picp 0.894118, pinew 0.639453
# svm
# Result of Cross validation:
# cwc 11.282261, picp 0.673611, pinew 0.403557
# Result of Test validation:
# cwc 0.923000, picp 0.847059, pinew 0.342114
# svm
# Result of Cross validation:
# cwc 2.119213, picp 0.548611, pinew 0.265893
# Result of Test validation:
# cwc 1.192491, picp 0.764706, pinew 0.244926
#
# Final Result:
# cwc 1.144380, picp 0.835294, pinew 0.408831
