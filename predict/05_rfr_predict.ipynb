# %% [markdown]
# # 随机森林回归

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit

import read_data as rd
from metrics import cwcf, picpf, pinewf

# %%
ts_sm, ts_tr, ts_pe = rd.load_sp()

# %%
ts = ts_sm

# %%
ts_u_train, ts_u_test, ts_l_train, ts_l_test, ts_train, ts_test = rd.split_train_test(ts)

# %%
tree_cv_u = RandomForestRegressor(n_estimators=20)
tree_cv_l = RandomForestRegressor(n_estimators=20)

tree_u = RandomForestRegressor(n_estimators=20)
tree_l = RandomForestRegressor(n_estimators=20)

# %%
from predict_fx import xxx_cross_validation, xxx_test_validation, predict_diff, predict_sp_diff

# %%
xxx_cross_validation(ts_train, ts_u_train, ts_l_train, tree_cv_u, tree_cv_l, is_plot=True, plt_no=311)
# Out:
# (3.920758896254609, 0.736111111111111, 0.5791380414350107)

# %%
xxx_test_validation(ts_test, ts_u_train, ts_u_test, ts_l_train, ts_l_test, tree_u, tree_l, is_plot=True)
# Out:
# (1.2356365525360862, 0.8941176470588236, 0.5996523883387024)

# %% [markdown]
# # 检验

# %% [markdown]
# ## smooth

# %%
predict_diff(ts_sm, model='rfr', is_plt=True)
# Out:
# rfr
# Result of Cross validation:
# cwc 2.991862, picp 0.763889, pinew 0.582240
# Result of Test validation:
# cwc 1.332234, picp 0.882353, pinew 0.607494
# (1.3322335622490347, 0.8823529411764706, 0.6074938278126225)

# %% [markdown]
# ## trend

# %%
predict_diff(ts_tr, model='rfr', is_plt=True)
# Out:
# rfr
# Result of Cross validation:
# cwc 8.008223, picp 0.687500, pinew 0.357061
# Result of Test validation:
# cwc 0.808876, picp 0.858824, pinew 0.322328
# (0.8088764429434241, 0.8588235294117647, 0.32232840803907903)

# %% [markdown]
# ## period

# %%
predict_diff(ts_sm, model='rfr', is_plt=True)
# Out:
# rfr
# Result of Cross validation:
# cwc 3.503831, picp 0.750000, pinew 0.586587
# Result of Test validation:
# cwc 0.582189, picp 0.941176, pinew 0.582189
# (0.5821886662839828, 0.9411764705882353, 0.5821886662839828)

# %%
predict_sp_diff('rfr')
# Out:
# Using rfr 'model' to predict
# rfr
# Result of Cross validation:
# cwc 3.771083, picp 0.743056, pinew 0.575996
# Result of Test validation:
# cwc 1.197887, picp 0.894118, pinew 0.581333
# rfr
# Result of Cross validation:
# cwc 6.765768, picp 0.694444, pinew 0.361373
# Result of Test validation:
# cwc 0.797844, picp 0.858824, pinew 0.317932
# rfr
# Result of Cross validation:
# cwc 86.277800, picp 0.673611, pinew 0.471091
# Result of Test validation:
# cwc 0.256290, picp 0.929412, pinew 0.256290
#
# Final Result:
# cwc 0.750674, picp 0.894118, pinew 0.385185
